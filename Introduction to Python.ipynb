# %%
print("Hello World")
# Out:
# Hello World

# %%
hello= "Hello Simplilearn"
print(hello)
# Out:
# Hello Simplilearn

# %%
name=input("Enter your name")
print("hi",name)
# Out:
# hi Hinga

# %%
print("Hope to see you in classsoon ")
# Out:
# Hope to see you in classsoon

# %%
this is a title
#this is a bigger title

# %% [markdown]
# Below is a diagram of a diagnol line

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,2,3,4])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 plt.plot([1,2,3,4],[1,2,3,4])
#       3 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib'
