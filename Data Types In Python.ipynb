# %%
num=5
type(num)
# Out:
# int

# %%
num=23575406471
type(num)
# Out:
# int

# %%
num=5.4
type(num)
# Out:
# float

# %%
num=2+5j
type(num)
# Out:
# complex

# %%
num.real
# Out:
# 2.0

# %%
num.imag
# Out:
# 5.0

# %%
num=-5647.675
num
# Out:
# -5647.675

# %%
num1=10
num2=2

# %%
print(num1+num2)
# Out:
# 12

# %%
print(num1-num2)
# Out:
# 8

# %%
print(num1*num2)
# Out:
# 20

# %%
print(num1/num2)
# Out:
# 5.0

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
print(10//3)
# Out:
# 3

# %%
print(num1**num2)
# Out:
# 100

# %%
print(num1%num2)
# Out:
# 0

# %% [markdown]
# Conversions

# %%
x="192"
type(x)
# Out:
# str

# %%
int(x)
# Out:
# 192

# %%
x=int(x)
type(x)
# Out:
# int

# %%
x=float(x)

# %%
print(x)
# Out:
# 192.0

# %%
x=complex(x)
print(x)
# Out:
# (192+0j)

# %%
print (complex(2,6))
# Out:
# (2+6j)

# %% [markdown]
# Functions
