# %% [markdown]
# while loop

# %%
val=int(input("Enter a multiple of 7: "))
while val%7!=0:
    val=int(input("Enter a multiple of 7: "))
else:
    print("%disamultipleof7"%val)
# Out:
# 42isamultipleof7

# %% [markdown]
# For Loop

# %%
x=[1,6,"simplilearn"]
for i in x :
    print(i)
# Out:
# 1
# 6
# simplilearn
