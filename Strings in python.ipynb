# %%
stg="Tim said,\"I'm busy today\"."
print(stg)
# Out:
# Tim said,"I'm busy today".

# %%
stg="hey there"
"Welcome to Simplilearn"""
print(stg)
# Out:
# hey there

# %%
stg="Simplilearn"
for i in stg:
    print(i)
# Out:
# S
# i
# m
# p
# l
# i
# l
# e
# a
# r
# n

# %%
stg="Simplilearn"
print(stg[0:5])
print(stg[:5])
print(stg[5:])
print(stg[2:5])
# Out:
# Simpl
# Simpl
# ilearn
# mpl

# %%
stg1="good"
stg="morning"
stg=stg1+" "+stg
print(stg)
# Out:
# good morning

# %%
stg1="Hey"
stg2="there"
stg3="all"
stg=stg1+" "+stg2+" "+stg3
print(stg)
# Out:
# Hey there all
