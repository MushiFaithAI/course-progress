# %%
x=[1,4.2,"simplilearn"]
for i in x :
    print (i)
# Out:
# 1
# 4.2
# simplilearn

# %%
x=[1,4.2,"simplilearn"]
for i in x:
    print(i,end="")
# Out:
# 14.2simplilearn

# %%
sum=0
for i in range (0,21):
    if i%2==0:
        sum=sum+i
print(sum)
# Out:
# 110

# %%
n=int(input("Enter aNumber"))
for i in range(1,n+1):
  for j in range(1,i+1):
      print(j,end="")
print()
# Out:
# 112123123412345

# %%
x=[1,2,3,3,"Simplilearn"]
lenght=0
i=0
try:
    while x[i]:
        length=+1
        i=i+1
except IndexError:
    print(length)
# Out:
# 1
